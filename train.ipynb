# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
from collections import Counter
pd.options.display.max_columns = None
pd.options.display.max_rows = None

def euclidean_distance(x1, x2):
    distance = np.sqrt(np.sum((x1-x2)**2))
    return distance


class KNN:
    def __init__(self, k=3):
        self.k = k

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, X):
        predictions = [self._predict(x) for x in X]
        return predictions

    def _predict(self, x):
        # compute the distance
        distances = [euclidean_distance(x, x_train) for x_train in self.X_train]
    
        # get the closest k
        k_indices = np.argsort(distances)[:self.k]
        k_nearest_labels = [self.y_train[i] for i in k_indices]

        # majority voye
        most_common = Counter(k_nearest_labels).most_common()
        return most_common[0][0]

# %%
cmap = ListedColormap(['#FF0000','#00FF00','#0000FF'])

df= pd.read_csv("pridiction.csv")

X = df[["SCORE","CLUSTER"]].values.astype(int)
y = df["RESULT "].values
df["CLUSTER"]
# Out:
# 0      10
# 1      10
# 2       4
# 3       6
# 4       6
# 5       5
# 6       6
# 7       8
# 8       4
# 9       4
# 10      6
# 11      0
# 12      4
# 13      4
# 14      4
# 15      3
# 16      0
# 17      0
# 18      4
# 19      4
# 20      3
# 21      3
# 22      0
# 23      4
# 24      0
# 25      0
# 26      2
# 27     10
# 28      2
# 29      4
# 30      3
# 31      8
# 32      9
# 33      3
# 34      3
# 35      3
# 36      0
# 37      3
# 38      4
# 39      4
# 40      3
# 41      4
# 42      3
# 43      9
# 44      6
# 45      4
# 46      4
# 47      3
# 48      9
# 49      6
# 50      4
# 51      4
# 52      4
# 53      4
# 54      6
# 55      3
# 56      2
# 57      3
# 58      4
# 59      0
# 60      3
# 61      6
# 62      4
# 63      4
# 64      4
# 65      8
# 66      0
# 67      3
# 68      3
# 69      3
# 70      8
# 71      0
# 72      4
# 73      3
# 74      0
# 75      3
# 76      3
# 77      2
# 78      4
# 79      3
# 80      2
# 81      3
# 82      3
# 83     10
# 84      3
# 85      3
# 86     10
# 87      5
# 88      3
# 89      8
# 90      3
# 91      7
# 92      3
# 93      4
# 94      4
# 95      6
# 96      4
# 97      0
# 98      3
# 99      6
# 100     3
# 101     6
# 102     6
# 103     4
# 104     4
# 105     3
# 106     3
# 107     8
# 108     4
# 109     3
# 110     7
# 111     3
# 112    10
# 113     8
# 114     6
# 115     3
# 116     3
# 117     4
# 118     5
# 119     4
# 120     7
# 121     4
# 122     3
# 123     3
# 124     4
# 125     0
# 126     3
# 127     2
# 128     9
# 129     4
# 130     5
# 131     3
# 132     3
# 133     9
# 134     6
# 135     6
# 136     8
# 137     8
# 138    10
# 139     8
# 140     8
# 141     4
# 142     4
# 143     7
# 144     3
# 145     5
# 146     6
# 147     5
# 148     0
# 149     0
# 150     0
# 151     3
# 152    10
# 153     4
# 154     4
# 155     7
# 156     8
# 157     9
# 158     9
# 159     0
# 160     3
# 161     3
# 162    10
# 163     0
# 164    10
# 165    10
# 166     8
# 167     8
# 168     3
# 169     3
# 170     4
# 171     9
# 172     2
# 173    10
# 174     3
# 175     3
# 176     8
# 177     3
# 178     8
# 179     3
# 180     3
# 181     3
# 182     8
# 183     8
# 184     4
# 185     3
# 186     0
# 187     3
# 188     3
# 189     3
# 190    10
# 191     6
# 192     3
# 193     4
# 194     6
# 195     0
# 196     3
# 197     6
# 198     4
# 199     3
# 200     3
# 201    10
# 202     4
# 203     3
# 204     8
# 205     3
# 206    10
# 207     6
# 208     0
# 209     6
# 210     0
# 211     3
# 212     0
# 213    10
# 214     1
# 215     0
# 216    10
# 217     3
# 218     9
# 219     3
# 220     5
# 221     9
# 222     3
# 223     4
# 224     4
# 225     3
# 226     3
# 227     3
# 228     4
# 229     3
# 230    10
# 231     6
# 232     9
# 233     0
# 234     8
# 235     4
# 236     0
# 237    10
# 238     3
# 239     0
# 240     3
# 241     4
# 242     3
# 243     8
# 244     3
# 245     3
# 246     4
# 247     3
# 248     4
# 249     4
# 250     3
# 251     6
# 252     3
# 253     4
# 254     8
# 255     8
# 256     3
# 257     6
# 258     3
# 259     4
# 260     3
# 261     3
# 262    10
# 263     3
# 264     4
# 265     3
# 266     4
# 267     9
# 268     6
# 269     3
# 270     3
# 271     4
# 272     3
# 273     3
# 274     4
# 275     3
# 276     4
# 277     3
# Name: CLUSTER, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

plt.figure()
plt.scatter(X[:,2],X[:,3], c=y, cmap=cmap, edgecolor='k', s=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [58], line 4
#       1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)
#       3 plt.figure()
# ----> 4 plt.scatter(X[:,2],X[:,3], c=y, cmap=cmap, edgecolor='k', s=20)
#       5 plt.show()
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
clf = KNN(k=5)
predictions = clf.predict(X_test)

print(predictions)

acc = np.sum(predictions == y_test) / len(y_test)
print(acc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [59], line 2
#       1 clf = KNN(k=5)
# ----> 2 predictions = clf.predict(X_test)
#       4 print(predictions)
#       6 acc = np.sum(predictions == y_test) / len(y_test)
#
# Cell In [49], line 25, in KNN.predict(self, X)
#      24 def predict(self, X):
# ---> 25     predictions = [self._predict(x) for x in X]
#      26     return predictions
#
# Cell In [49], line 25, in <listcomp>(.0)
#      24 def predict(self, X):
# ---> 25     predictions = [self._predict(x) for x in X]
#      26     return predictions
#
# Cell In [49], line 30, in KNN._predict(self, x)
#      28 def _predict(self, x):
#      29     # compute the distance
# ---> 30     distances = [euclidean_distance(x, x_train) for x_train in self.X_train]
#      32     # get the closest k
#      33     k_indices = np.argsort(distances)[:self.k]
#
# AttributeError: 'KNN' object has no attribute 'X_train'
